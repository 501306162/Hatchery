# %%
using NRIRHOPM, FileIO, Images, Plots, Interpolations, Memento; gr()
# Out:
# WARNING: Base.ByteString is deprecated, use String instead.
#   likely near /Users/gnimuc/.julia/v0.5/NIfTI/src/NIfTI.jl:88
# Plots.GRBackend()

# %%
import NRIRHOPM: constrain!

# %%
include("draw2.jl")

# %%
circle = Gray.(load("./ring.png"))
# Out:
# 130×129 Array{Gray{N0f8},2}:
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                   ⋱
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.012)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)

# %%
square = Gray.(load("./square.png"))
# Out:
# 129×130 Array{Gray{N0f8},2}:
#  Gray{N0f8}(0.118)  Gray{N0f8}(0.035)  …  Gray{N0f8}(0.192)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)    …  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)    …  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)    …  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)    …  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.0)       Gray{N0f8}(0.0)

# %%
size(circle), size(square), typeof(circle)
# Out:
# ((130,129),(129,130),Array{ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}},2})

# %%
square, circle = restrict(square), restrict(circle);

# %%
fixed, moving = square[1:64,1:64],  circle[1:64,1:64];

# %%
function hopm_canonical2(𝐭::AbstractMatrix, 𝐓::BlockedTensor, 𝐌::AbstractMatrix,
                        tol::Real, maxIter::Integer,a
                       )
    e, 𝐯 = hopm_canonical2(reshape(𝐭, length(𝐭)), 𝐓, reshape(𝐌, length(𝐌)), tol, maxIter,a)
    return e, reshape(𝐯, size(𝐭))
end

function hopm_canonical2(𝐭::AbstractMatrix, 𝐓::BlockedTensor, 𝑻::BlockedTensor, 𝐌::AbstractMatrix,
                        tol::Real, maxIter::Integer,a,b
                       )
    e, 𝐯 = hopm_canonical2(reshape(𝐭, length(𝐭)), 𝐓, 𝑻, reshape(𝐌, length(𝐌)), tol, maxIter,a,b)
    return e, reshape(𝐯, size(𝐭))
end

function hopm_canonical2(𝐭::AbstractVector, 𝐓::BlockedTensor, 𝐯::AbstractVector,
    tol::Real, maxIter::Integer, a::Float64
                       )
    𝐯₀ = copy(𝐯)
    normalize!(𝐯₀)
    𝐯ᵢ = 𝐯₀
    i = 0
    while i < maxIter
        i += 1
        𝐯ᵢ₊₁ = 𝐯ᵢ .* 𝐭 + a*(𝐓 ⊙ 𝐯ᵢ)
        normalize!(𝐯ᵢ₊₁)
        if vecnorm(𝐯ᵢ₊₁ - 𝐯ᵢ) < tol
            𝐯ᵢ = 𝐯ᵢ₊₁
            break
        end
        𝐯ᵢ = 𝐯ᵢ₊₁
    end
    logger = get_logger(current_module())
    i == maxIter && warn(logger, "Maximum iterator number is reached, the result might not be convergent.")
    i < maxIter && info(logger, "HOPM converges in $i steps.")
    return 𝐯ᵢ ⋅ (𝐯ᵢ .* 𝐭 + a*(𝐓 ⊙ 𝐯ᵢ)), 𝐯ᵢ
end

function hopm_canonical2(𝐭::AbstractVector, 𝐓::BlockedTensor, 𝑻::BlockedTensor, 𝐯::AbstractVector,
    tol::Real, maxIter::Integer, a::Float64, b::Float64
                       )
    𝐯₀ = copy(𝐯)
    normalize!(𝐯₀)
    𝐯ᵢ = 𝐯₀
    i = 0
    while i < maxIter
        i += 1
        𝐯ᵢ₊₁ = 𝐯ᵢ .* 𝐯ᵢ .* 𝐭 + a*(𝐯ᵢ .* (𝐓 ⊙ 𝐯ᵢ)) + b*(𝑻 ⊙ 𝐯ᵢ)
        normalize!(𝐯ᵢ₊₁)
        if vecnorm(𝐯ᵢ₊₁ - 𝐯ᵢ) < tol
            𝐯ᵢ = 𝐯ᵢ₊₁
            break
        end
        𝐯ᵢ = 𝐯ᵢ₊₁
    end
    logger = get_logger(current_module())
    i == maxIter && warn(logger, "Maximum iterator number is reached, the result might not be convergent.")
    i < maxIter && info(logger, "HOPM converges in $i steps.")
    return 𝐯ᵢ ⋅ (𝐯ᵢ .* 𝐯ᵢ .* 𝐭 + a*(𝐯ᵢ .* (𝐓 ⊙ 𝐯ᵢ)) + b*(𝑻 ⊙ 𝐯ᵢ)), 𝐯ᵢ
end
# Out:
# hopm_canonical2 (generic function with 4 methods)

# %%
immutable HOPM2{F<:Function,Tt<:Real,Tm<:Integer} <: AbstractHOPMMethod
    f::F
    tolerance::Tt
    maxIteration::Tm
    a::Float64
end
HOPM2(tolerance, maxIteration,a) = HOPM2(hopm_canonical2, tolerance, maxIteration,a)
HOPM2(; tolerance=1e-5, maxIteration=300,a=1) = HOPM2( tolerance, maxIteration,a)

immutable HOPM3{F<:Function,Tt<:Real,Tm<:Integer} <: AbstractHOPMMethod
    f::F
    tolerance::Tt
    maxIteration::Tm
    a::Float64
    b::Float64
end
HOPM3( tolerance, maxIteration,a,b) = HOPM3(hopm_canonical2,  tolerance, maxIteration,a,b)
HOPM3(; tolerance=1e-5, maxIteration=300,a=1,b=1) = HOPM3( tolerance, maxIteration,a,b)
# Out:
# HOPM3{F<:Function,Tt<:Real,Tm<:Integer}

# %%
# displacements = [SVector(i,j) for i in -3:3, j in -3:3]
# displacements2 = [SVector(i,j) for i in -1:1, j in -1:1]
displacetopo = [SVector(i,j) for i in -2:2, j in -2:2]
displacementSet = [displacetopo,displacetopo]#, displacements, displacements2]
gridSet = [(32,32),(32,32)] #,(64,64),(128,128)]
originΔ = vecnorm(moving-fixed)
warpped, d, spec, energy = multilevel(fixed, moving, displacementSet, gridSet, topology=NRIRHOPM.TP2D(), 
α=1, β=1, χ=0, method=HOPM2(maxIteration=20,a=0.001))
topologyΔ = vecnorm(warpped[end]-fixed)
# Out:
# [ 2017-03-04T11:54:33 | info ]: Start multilevel processing...
# [ 2017-03-04T11:54:33 | info ]: Level 1:
# [ 2017-03-04T11:54:33 | info ]: Image Dimension: (64,64)
# [ 2017-03-04T11:54:33 | info ]: Grid Dimension: (32,32)
# [ 2017-03-04T11:54:33 | info ]: Creating data cost with weight=1:
# [ 2017-03-04T11:54:34 | info ]:   0.329515 seconds (1.50 M allocations: 42.086 MB, 16.63% gc time)
# [ 2017-03-04T11:54:34 | info ]: Creating smooth cost with weight=1:
# [ 2017-03-04T11:54:34 | info ]:   0.092273 seconds (34.35 k allocations: 1.566 MB)
# [ 2017-03-04T11:54:34 | info ]: Optimizing via High Order Power Method:
# [ 2017-03-04T11:54:35 | warn ]: Maximum iterator number is reached, the result might not be convergent.
# [ 2017-03-04T11:54:35 | info ]:   0.985411 seconds (98.27 k allocations: 33.289 MB, 14.96% gc time)
# [ 2017-03-04T11:54:37 | info ]: Multilevel processing done!
# 7.060394609715359

# %%
displacetopo = [SVector(i,j) for i in -3:3, j in -3:3]
displacementSet = [displacetopo]
gridSet = [(32,32)]
warpped, d, spec, energy = multilevel(fixed, moving, displacementSet, gridSet, topology=NRIRHOPM.TP2D(), 
α=1, β=1, χ=1, method=HOPM3(maxIteration=20,a=0.001,b=0.001))
topologyΔ = vecnorm(warpped[end]-fixed)
# Out:
# [ 2017-03-04T12:02:19 | info ]: Start multilevel processing...
# [ 2017-03-04T12:02:19 | info ]: Level 0:
# [ 2017-03-04T12:02:19 | info ]: Image Dimension: (64,64)
# [ 2017-03-04T12:02:19 | info ]: Grid Dimension: (32,32)
# [ 2017-03-04T12:02:19 | info ]: Creating data cost with weight=1:
# [ 2017-03-04T12:02:19 | info ]:   0.387828 seconds (2.89 M allocations: 81.664 MB, 7.14% gc time)
# [ 2017-03-04T12:02:19 | info ]: Creating smooth cost with weight=1:
# [ 2017-03-04T12:02:19 | info ]:   0.000817 seconds (34 allocations: 167.172 KB)
# [ 2017-03-04T12:02:19 | info ]: Creating topology cost with weight=1:
# [ 2017-03-04T12:02:19 | info ]:   0.039836 seconds (97 allocations: 7.373 MB)
# [ 2017-03-04T12:02:19 | info ]: Optimizing via High Order Power Method:

# %%
colorview(Gray, warpped[1])
# Out:
# 64×64 Array{Gray{Float64},2}:
#  Gray{Float64}(0.0)           …  Gray{Float64}(7.42781e-313)
#  Gray{Float64}(1.12466e-312)     Gray{Float64}(6.95022e-310)
#  Gray{Float64}(0.0)              Gray{Float64}(6.95022e-310)
#  Gray{Float64}(6.95022e-310)     Gray{Float64}(6.95022e-310)
#  Gray{Float64}(NaN)              Gray{Float64}(7.63918e-313)
#  Gray{Float64}(6.95022e-310)  …  Gray{Float64}(6.95022e-310)
#  Gray{Float64}(NaN)              Gray{Float64}(6.95022e-310)
#  Gray{Float64}(6.95017e-310)     Gray{Float64}(6.95022e-310)
#  Gray{Float64}(NaN)              Gray{Float64}(-1.46418e-311)
#  Gray{Float64}(6.95022e-310)     Gray{Float64}(6.95022e-310)
#  Gray{Float64}(NaN)           …  Gray{Float64}(4.94066e-324)
#  Gray{Float64}(6.95022e-310)     Gray{Float64}(0.0)
#  Gray{Float64}(NaN)              Gray{Float64}(0.0)
#  ⋮                            ⋱
#  Gray{Float64}(NaN)              Gray{Float64}(0.0)
#  Gray{Float64}(4.24399e-314)     Gray{Float64}(0.0)
#  Gray{Float64}(NaN)              Gray{Float64}(6.95022e-310)
#  Gray{Float64}(6.95022e-310)  …  Gray{Float64}(6.95022e-310)
#  Gray{Float64}(NaN)              Gray{Float64}(6.95022e-310)
#  Gray{Float64}(1.9098e-313)      Gray{Float64}(4.94066e-324)
#  Gray{Float64}(NaN)              Gray{Float64}(6.95022e-310)
#  Gray{Float64}(6.95022e-310)     Gray{Float64}(NaN)
#  Gray{Float64}(NaN)           …  Gray{Float64}(0.0)
#  Gray{Float64}(5.30499e-313)     Gray{Float64}(0.0)
#  Gray{Float64}(NaN)              Gray{Float64}(6.95022e-310)
#  Gray{Float64}(6.95022e-310)     Gray{Float64}(6.95022e-310)

# %%
colorview(Gray, warpped[end])
# Out:
# 64×64 Array{Gray{Float64},2}:
#  Gray{Float64}(0.0)           …  Gray{Float64}(7.42781e-313)
#  Gray{Float64}(1.12466e-312)     Gray{Float64}(6.95022e-310)
#  Gray{Float64}(0.0)              Gray{Float64}(6.95022e-310)
#  Gray{Float64}(6.95022e-310)     Gray{Float64}(6.95022e-310)
#  Gray{Float64}(NaN)              Gray{Float64}(7.63918e-313)
#  Gray{Float64}(6.95022e-310)  …  Gray{Float64}(6.95022e-310)
#  Gray{Float64}(NaN)              Gray{Float64}(6.95022e-310)
#  Gray{Float64}(6.95017e-310)     Gray{Float64}(6.95022e-310)
#  Gray{Float64}(NaN)              Gray{Float64}(-1.46418e-311)
#  Gray{Float64}(6.95022e-310)     Gray{Float64}(6.95022e-310)
#  Gray{Float64}(NaN)           …  Gray{Float64}(4.94066e-324)
#  Gray{Float64}(6.95022e-310)     Gray{Float64}(0.0)
#  Gray{Float64}(NaN)              Gray{Float64}(0.0)
#  ⋮                            ⋱
#  Gray{Float64}(NaN)              Gray{Float64}(0.0)
#  Gray{Float64}(4.24399e-314)     Gray{Float64}(0.0)
#  Gray{Float64}(NaN)              Gray{Float64}(6.95022e-310)
#  Gray{Float64}(6.95022e-310)  …  Gray{Float64}(6.95022e-310)
#  Gray{Float64}(NaN)              Gray{Float64}(6.95022e-310)
#  Gray{Float64}(1.9098e-313)      Gray{Float64}(4.94066e-324)
#  Gray{Float64}(NaN)              Gray{Float64}(6.95022e-310)
#  Gray{Float64}(6.95022e-310)     Gray{Float64}(NaN)
#  Gray{Float64}(NaN)           …  Gray{Float64}(0.0)
#  Gray{Float64}(5.30499e-313)     Gray{Float64}(0.0)
#  Gray{Float64}(NaN)              Gray{Float64}(6.95022e-310)
#  Gray{Float64}(6.95022e-310)     Gray{Float64}(6.95022e-310)

# %%
displacementfield(meshgrid(d[end])...; xyInv=true, size=(300,300)) # a=0.001 only 2000
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="300" height