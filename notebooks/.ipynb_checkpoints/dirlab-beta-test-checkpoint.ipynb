# %%
using NRIRHOPM, Plots #, FileIO, Images, Plots, Interpolations, Memento; gr()
# Out:
# WARNING: Base.ByteString is deprecated, use String instead.
#   likely near C:\Users\qyp\AppData\Local\JuliaPro-0.5.1.1\pkgs-0.5.1.1\v0.5\NIfTI\src\NIfTI.jl:88

# %%
Pkg.dir("NRIRHOPM")
# Out:
# "C:\\Users\\qyp\\AppData\\Local\\JuliaPro-0.5.1.1\\pkgs-0.5.1.1\\v0.5\\NRIRHOPM"

# %%
fixed = readDIRLab("C:\\Users\\qyp\\Dropbox\\CTdata\\case5_T00-ssm.img", NRIRHOPM.DIRLab4DCT5);

# %%
moving = readDIRLab("C:\\Users\\qyp\\Dropbox\\CTdata\\case5_T50-ssm.img", NRIRHOPM.DIRLab4DCT5);

# %%
originΔ = vecnorm(moving-fixed)
# Out:
# 327870.38476507756

# %%
displace = [SVector(i,j,k) for i in -1:1, j in -1:1, k in -1:1]
displacements32 = [SVector(i,j,k) for i in -6:6, j in -6:6, k in -6:6]
displacements42 = [SVector(i,j,k) for i in -5:5, j in -5:5, k in -5:5]
displacements64 = [SVector(i,j,k) for i in -4:4, j in -4:4, k in -4:4]
displacements85 = [SVector(i,j,k) for i in -3:3, j in -3:3, k in -3:3]
displacements128 = [SVector(i,j,k) for i in -2:2, j in -2:2, k in -2:2]
# displacementSet = [displacetopo, displacements32, displacements64, displacements128]
displacementSet = [displace, displace, displace, displace, displace, displace]
gridSet = [(32,32,13),(42,42,17),(64,64,26),(85,85,35),(128,128,53),(256,256,106)]
warpped, d, spec, energy = multilevel(fixed, moving, displacementSet, gridSet, MixHOPM(maxIteration=30), SAD(), ones(6), TAD(), [0,0,0,0,0,0])
topologyΔ = vecnorm(warpped[end]-fixed)
# Out:
# [ 2017-03-22T16:18:55 | info ]: Start multilevel processing...
# [ 2017-03-22T16:18:55 | info ]: Level 1:
# [ 2017-03-22T16:18:55 | info ]: Image Dimension: (256,256,106)
# [ 2017-03-22T16:18:55 | info ]: Grid Dimension: (32,32,13)
# [ 2017-03-22T16:18:55 | info ]: Creating data cost with weight=1.0:
# [ 2017-03-22T16:19:03 | info ]:   7.562498 seconds (7 allocations: 5.485 MB)
# [ 2017-03-22T16:19:03 | info ]: Creating smooth cost with weight=0:
# [ 2017-03-22T16:19:03 | info ]:   0.012787 seconds (26 allocations: 5.012 MB)
# [ 2017-03-22T16:19:03 | info ]: Optimizing via High Order Power Method:
# [ 2017-03-22T16:19:03 | info ]: HOPM converges in 2 steps.
# [ 2017-03-22T16:19:03 | info ]:   0.573343 seconds (2.19 k allocations: 38.544 MB, 32.63% gc time)
# [ 2017-03-22T16:19:14 | notice ]: 0 outbounds voxels
# [ 2017-03-22T16:19:14 | info ]: Level 2:
# [ 2017-03-22T16:19:14 | info ]: Image Dimension: (256,256,106)
# [ 2017-03-22T16:19:14 | info ]: Grid Dimension: (42,42,17)
# [ 2017-03-22T16:19:14 | info ]: Creating data cost with weight=1.0:
# [ 2017-03-22T16:19:20 | info ]:   6.132969 seconds (7 allocations: 12.355 MB, 0.04% gc time)
# [ 2017-03-22T16:19:20 | info ]: Creating smooth cost with weight=0:
# [ 2017-03-22T16:19:20 | info ]:   0.011622 seconds (27 allocations: 9.012 MB)
# [ 2017-03-22T16:19:20 | info ]: Optimizing via High Order Power Method:
# [ 2017-03-22T16:19:21 | info ]: HOPM converges in 2 steps.
# [ 2017-03-22T16:19:21 | info ]:   0.657423 seconds (2.18 k allocations: 86.637 MB, 1.11% gc time)
# [ 2017-03-22T16:19:33 | notice ]: 803 outbounds voxels
# [ 2017-03-22T16:19:33 | info ]: Level 3:
# [ 2017-03-22T16:19:33 | info ]: Image Dimension: (256,256,106)
# [ 2017-03-22T16:19:33 | info ]: Grid Dimension: (64,64,26)
# [ 2017-03-22T16:19:33 | info ]: Creating data cost with weight=1.0:
# [ 2017-03-22T16:19:40 | info ]:   7.286077 seconds (7 allocations: 43.875 MB, 0.06% gc time)
# [ 2017-03-22T16:19:40 | info ]: Creating smooth cost with weight=0:
# [ 2017-03-22T16:19:40 | info ]:   0.061644 seconds (29 allocations: 33.012 MB, 1.86% gc time)
# [ 2017-03-22T16:19:41 | info ]: Optimizing via High Order Power Method:
# [ 2017-03-22T16:19:42 | info ]: HOPM converges in 2 steps.
# [ 2017-03-22T16:19:43 | info ]:   2.634285 seconds (2.18 k allocations: 307.278 MB, 24.48% gc time)
# [ 2017-03-22T16:19:55 | notice ]: 2050 outbounds voxels
# [ 2017-03-22T16:19:55 | info ]: Level 4:
# [ 2017-03-22T16:19:55 | info ]: Image Dimension: (256,256,106)
# [ 2017-03-22T16:19:55 | info ]: Grid Dimension: (85,85,35)
# [ 2017-03-22T16:19:55 | info ]: Creating data cost with weight=1.0:
# [ 2017-03-22T16:20:03 | info ]:   7.987932 seconds (7 allocations: 104.182 MB, 0.06% gc time)
# [ 2017-03-22T16:20:03 | info ]: Creating smooth cost with weight=0:
# [ 2017-03-22T16:20:04 | info ]:   0.182056 seconds (30 allocations: 65.012 MB, 22.08% gc time)
# [ 2017-03-22T16:20:04 | info ]: Optimizing via High Order Power Method:
# [ 2017-03-22T16:20:07 | info ]: HOPM converges in 2 steps.
# [ 2017-03-22T16:20:09 | info ]:   5.332222 seconds (2.19 k allocations: 729.424 MB, 15.05% gc time)
# [ 2017-03-22T16:20:20 | notice ]: 4354 outbounds voxels
# [ 2017-03-22T16:20:20 | info ]: Level 5:
# [ 2017-03-22T16:20:20 | info ]: Image Dimension: (256,256,106)
# [ 2017-03-22T16:20:20 | info ]: Grid Dimension: (128,128,53)
# [ 2017-03-22T16:20:20 | info ]: Creating data cost with weight=1.0:
# [ 2017-03-22T16:20:28 | info ]:   7.704622 seconds (7 allocations: 357.750 MB, 0.08% gc time)
# [ 2017-03-22T16:20:28 | info ]: Creating smooth cost with weight=0:
# [ 2017-03-22T16:20:29 | info ]:   0.495513 seconds (32 allocations: 129.012 MB, 24.09% gc time)
# [ 2017-03-22T16:20:29 | info ]: Optimizing via High Order Power Method:
# [ 2017-03-22T16:20:40 | info ]: HOPM converges in 2 steps.
# [ 2017-03-22T16:20:45 | info ]:  15.881542 seconds (2.18 k allocations: 2.446 GB, 4.65% gc time)
# [ 2017-03-22T16:20:56 | notice ]: 0 outbounds voxels
# [ 2017-03-22T16:20:56 | info ]: Level 6:
# [ 2017-03-22T16:20:56 | info ]: Image Dimension: (256,256,106)
# [ 2017-03-22T16:20:56 | info ]: Grid Dimension: (256,256,106)
# [ 2017-03-22T16:20:56 | info ]: Creating data cost with weight=1.0:
# [ 2017-03-22T16:21:09 | info ]:  13.102612 seconds (7 allocations: 2.795 GB, 0.27% gc time)
# [ 2017-03-22T16:21:09 | info ]: Creating smooth cost with weight=0:
# [ 2017-03-22T16:21:13 | info ]:   4.230336 seconds (35 allocations: 2.001 GB, 15.00% gc time)
# [ 2017-03-22T16:21:13 | info ]: Optimizing via High Order Power Method:
# [ 2017-03-22T16:22:34 | info ]: HOPM converges in 2 steps.
# [ 2017-03-22T16:23:12 | info ]: 118.157009 seconds (2.18 k allocations: 19.565 GB, 1.21% gc time)
# [ 2017-03-22T16:23:26 | notice ]: 61 outbounds voxels
# [ 2017-03-22T16:23:26 | info ]: Multilevel processing done!
# 123553.97923821656

# %%
vecnorm(warpped[end]-fixed) - originΔ
# Out:
# -204316.405526861

# %%
displacetopo = [SVector(i,j,k) for i in -2:2, j in -2:2, k in -2:2]
displacements32 = [SVector(i,j,k) for i in -5:5, j in -5:5, k in -5:5]
displacements42 = [SVector(i,j,k) for i in -4:4, j in -4:4, k in -4:4]
displacements64 = [SVector(i,j,k) for i in -3:3, j in -3:3, k in -3:3]
displacements85 = [SVector(i,j,k) for i in -2:2, j in -2:2, k in -2:2]
displacements128 = [SVector(i,j,k) for i in -1:1, j in -1:1, k in -1:1]
displacementSet = [displacetopo, displacements32, displacements42, displacements64, displacements85, displacements128]
gridSet = [(32,32,26),(32,32,13),(42,42,17),(64,64,26),(85,85,35),(128,128,53)]
warpped, d, spec, energy = multilevel(fixed, moving, displacementSet, gridSet, 
α=1, β=2, χ=0, method=MixHOPM(maxIteration=50))
topologyΔ = vecnorm(warpped[end]-fixed)
# Out:
# [ 2017-03-21T19:06:33 | info ]: Start multilevel processing...
# [ 2017-03-21T19:06:33 | info ]: Level 1:
# [ 2017-03-21T19:06:33 | info ]: Image Dimension: (256,256,106)
# [ 2017-03-21T19:06:33 | info ]: Grid Dimension: (32,32,13)
# [ 2017-03-21T19:06:33 | info ]: Creating data cost with weight=1:
# [ 2017-03-21T19:11:03 | info ]: 270.478990 seconds (7 allocations: 270.360 MB, 0.12% gc time)
# [ 2017-03-21T19:11:03 | info ]: Creating smooth cost with weight=2:
# [ 2017-03-21T19:11:03 | info ]:   0.229259 seconds (28 allocations: 32.033 MB, 7.16% gc time)
# [ 2017-03-21T19:11:03 | info ]: Optimizing via High Order Power Method:
# [ 2017-03-21T19:21:07 | info ]: HOPM converges in 4 steps.
# [ 2017-03-21T19:23:39 | info ]: 755.324270 seconds (2.35 k allocations: 2.904 GB, 0.21% gc time)
# outboudscount = 0
# [ 2017-03-21T19:23:50 | info ]: Level 2:
# [ 2017-03-21T19:23:50 | info ]: Image Dimension: (256,256,106)
# [ 2017-03-21T19:23:50 | info ]: Grid Dimension: (42,42,17)
# [ 2017-03-21T19:23:50 | info ]: Creating data cost with weight=1:
# [ 2017-03-21T19:26:41 | info ]: 171.181436 seconds (7 allocations: 333.577 MB, 0.00% gc time)
# [ 2017-03-21T19:26:41 | info ]: Creating smooth cost with weight=2:
# [ 2017-03-21T19:26:41 | info ]:   0.053545 seconds (29 allocations: 17.110 MB)
# [ 2017-03-21T19:26:41 | info ]: Optimizing via High Order Power Method:
# [ 2017-03-21T19:35:26 | info ]: HOPM converges in 5 steps.
# [ 2017-03-21T19:37:12 | info ]: 630.598681 seconds (2.35 k allocations: 4.235 GB, 0.27% gc time)
# outboudscount = 940
# [ 2017-03-21T19:37:23 | info ]: Level 3:
# [ 2017-03-21T19:37:23 | info ]: Image Dimension: (256,256,106)
# [ 2017-03-21T19:37:23 | info ]: Grid Dimension: (64,64,26)
# [ 2017-03-21T19:37:23 | info ]: Creating data cost with weight=1:
# [ 2017-03-21T19:38:48 | info ]:  85.700543 seconds (7 allocations: 557.375 MB, 0.01% gc time)
# [ 2017-03-21T19:38:49 | info ]: Creating smooth cost with weight=2:
# [ 2017-03-21T19:38:49 | info ]:   0.067205 seconds (31 allocations: 34.796 MB, 1.84% gc time)
# [ 2017-03-21T19:38:49 | info ]: Optimizing via High Order Power Method:
# [ 2017-03-21T19:45:50 | info ]: HOPM converges in 5 steps.
# [ 2017-03-21T19:47:14 | info ]: 505.370610 seconds (2.35 k allocations: 7.076 GB, 0.37% gc time)
# outboudscount = 5745
# [ 2017-03-21T19:47:26 | info ]: Level 4:
# [ 2017-03-21T19:47:26 | info ]: Image Dimension: (256,256,106)
# [ 2017-03-21T19:47:26 | info ]: Grid Dimension: (85,85,35)
# [ 2017-03-21T19:47:26 | info ]: Creating data cost with weight=1:
# [ 2017-03-21T19:47:58 | info ]:  31.924117 seconds (7 allocations: 482.321 MB, 0.01% gc time)
# [ 2017-03-21T19:47:58 | info ]: Creating smooth cost with weight=2:
# [ 2017-03-21T19:47:58 | info ]:   0.119627 seconds (32 allocations: 65.240 MB, 13.89% gc time)
# [ 2017-03-21T19:47:58 | info ]: Optimizing via High Order Power Method:
# [ 2017-03-21T19:50:46 | info ]: HOPM converges in 6 steps.
# [ 2017-03-21T19:51:14 | info ]: 196.158840 seconds (2.36 k allocations: 7.065 GB, 1.08% gc time)
# outboudscount = 6266
# [ 2017-03-21T19:51:25 | info ]: Level 5:
# [ 2017-03-21T19:51:25 | info ]: Image Dimension: (256,256,106)
# [ 2017-03-21T19:51:25 | info ]: Grid Dimension: (128,128,53)
# [ 2017-03-21T19:51:25 | info ]: Creating data cost with weight=1:
# [ 2017-03-21T19:51:34 | info ]:   8.332988 seconds (7 allocations: 357.750 MB, 0.04% gc time)
# [ 2017-03-21T19:51:34 | info ]: Creating smooth cost with weight=2:
# [ 2017-03-21T19:51:34 | info ]:   0.538825 seconds (32 allocations: 129.012 MB, 21.84% gc time)
# [ 2017-03-21T19:51:34 | info ]: Optimizing via High Order Power Method:
# [ 2017-03-21T19:52:09 | info ]: HOPM converges in 6 steps.
# [ 2017-03-21T19:52:15 | info ]:  40.763502 seconds (2.37 k allocations: 5.241 GB, 4.95% gc time)
# outboudscount = 1395
# [ 2017-03-21T19:52:26 | info ]: Multilevel processing done!
# 331885.85960710404

# %%
sliceNum = 100

# %%
colorview(Gray, warpped[end][:,:,sliceNum] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float64,2,Array{Float64,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.0130891)   …  Gray{Float64}(0.0143533)
#  Gray{Float64}(0.0130891)      Gray{Float64}(0.0118883)
#  Gray{Float64}(0.0130769)      Gray{Float64}(0.0117588)
#  Gray{Float64}(0.0138425)      Gray{Float64}(0.014507)
#  Gray{Float64}(0.0108389)      Gray{Float64}(0.014507)
#  Gray{Float64}(0.0143673)   …  Gray{Float64}(0.0120594)
#  Gray{Float64}(0.0143673)      Gray{Float64}(0.0120516)
#  Gray{Float64}(0.0100569)      Gray{Float64}(0.0152148)
#  Gray{Float64}(0.00957471)     Gray{Float64}(0.0151538)
#  Gray{Float64}(0.0130038)      Gray{Float64}(0.0151538)
#  Gray{Float64}(0.0130038)   …  Gray{Float64}(0.0147873)
#  Gray{Float64}(0.0128451)      Gray{Float64}(0.012404)
#  Gray{Float64}(0.0100721)      Gray{Float64}(0.0146887)
#  ⋮                          ⋱  ⋮
#  Gray{Float64}(0.0364374)      Gray{Float64}(0.0316372)
#  Gray{Float64}(0.0315772)   …  Gray{Float64}(0.0333086)
#  Gray{Float64}(0.031929)       Gray{Float64}(0.0344843)
#  Gray{Float64}(0.031929)       Gray{Float64}(0.0342402)
#  Gray{Float64}(0.0291239)      Gray{Float64}(0.032816)
#  Gray{Float64}(0.0349546)      Gray{Float64}(0.0355224)
#  Gray{Float64}(0.0314938)   …  Gray{Float64}(0.0355224)
#  Gray{Float64}(0.0314938)      Gray{Float64}(0.036692)
#  Gray{Float64}(0.0314938)      Gray{Float64}(0.0313903)
#  Gray{Float64}(0.0379665)      Gray{Float64}(0.0312912)
#  Gray{Float64}(0.0379665)      Gray{Float64}(0.030938)
#  Gray{Float64}(0.0348676)   …  Gray{Float64}(0.0363039)

# %%
colorview(Gray, warpped[end][:,:,sliceNum] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float64,2,Array{Float64,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.0130891)   …  Gray{Float64}(0.0143533)
#  Gray{Float64}(0.0130891)      Gray{Float64}(0.0118883)
#  Gray{Float64}(0.0130769)      Gray{Float64}(0.0117588)
#  Gray{Float64}(0.0138425)      Gray{Float64}(0.014507)
#  Gray{Float64}(0.0108389)      Gray{Float64}(0.014507)
#  Gray{Float64}(0.0143673)   …  Gray{Float64}(0.0120594)
#  Gray{Float64}(0.0143673)      Gray{Float64}(0.0120516)
#  Gray{Float64}(0.0100569)      Gray{Float64}(0.0152148)
#  Gray{Float64}(0.00957471)     Gray{Float64}(0.0151538)
#  Gray{Float64}(0.0130038)      Gray{Float64}(0.0151538)
#  Gray{Float64}(0.0130038)   …  Gray{Float64}(0.0147873)
#  Gray{Float64}(0.0128451)      Gray{Float64}(0.012404)
#  Gray{Float64}(0.0100721)      Gray{Float64}(0.0146887)
#  ⋮                          ⋱  ⋮
#  Gray{Float64}(0.0364374)      Gray{Float64}(0.0316372)
#  Gray{Float64}(0.0315772)   …  Gray{Float64}(0.0333086)
#  Gray{Float64}(0.031929)       Gray{Float64}(0.0344843)
#  Gray{Float64}(0.031929)       Gray{Float64}(0.0342402)
#  Gray{Float64}(0.0291239)      Gray{Float64}(0.032816)
#  Gray{Float64}(0.0349546)      Gray{Float64}(0.0355224)
#  Gray{Float64}(0.0314938)   …  Gray{Float64}(0.0355224)
#  Gray{Float64}(0.0314938)      Gray{Float64}(0.036692)
#  Gray{Float64}(0.0314938)      Gray{Float64}(0.0313903)
#  Gray{Float64}(0.0379665)      Gray{Float64}(0.0312912)
#  Gray{Float64}(0.0379665)      Gray{Float64}(0.030938)
#  Gray{Float64}(0.0348676)   …  Gray{Float64}(0.0363039)

# %%
colorview(Gray, fixed[:,:,sliceNum] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float64,2,Array{Float64,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.0121536)  …  Gray{Float64}(0.010209)
#  Gray{Float64}(0.0165289)     Gray{Float64}(0.00583374)
#  Gray{Float64}(0.0204181)     Gray{Float64}(0.0131259)
#  Gray{Float64}(0.0140982)     Gray{Float64}(0.0150705)
#  Gray{Float64}(0.0145843)     Gray{Float64}(0.0097229)
#  Gray{Float64}(0.0170151)  …  Gray{Float64}(0.00923675)
#  Gray{Float64}(0.0160428)     Gray{Float64}(0.0150705)
#  Gray{Float64}(0.0121536)     Gray{Float64}(0.0097229)
#  Gray{Float64}(0.0116675)     Gray{Float64}(0.0043753)
#  Gray{Float64}(0.0131259)     Gray{Float64}(0.0126398)
#  Gray{Float64}(0.0106952)  …  Gray{Float64}(0.0126398)
#  Gray{Float64}(0.0111813)     Gray{Float64}(0.0116675)
#  Gray{Float64}(0.0136121)     Gray{Float64}(0.00875061)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.026738)      Gray{Float64}(0.0364609)
#  Gray{Float64}(0.0281964)  …  Gray{Float64}(0.0311133)
#  Gray{Float64}(0.0247934)     Gray{Float64}(0.0247934)
#  Gray{Float64}(0.0296548)     Gray{Float64}(0.0243072)
#  Gray{Float64}(0.0252795)     Gray{Float64}(0.0325717)
#  Gray{Float64}(0.0277103)     Gray{Float64}(0.0272241)
#  Gray{Float64}(0.0296548)  …  Gray{Float64}(0.0306271)
#  Gray{Float64}(0.026738)      Gray{Float64}(0.0286825)
#  Gray{Float64}(0.0296548)     Gray{Float64}(0.0277103)
#  Gray{Float64}(0.0252795)     Gray{Float64}(0.033544)
#  Gray{Float64}(0.0272241)     Gray{Float64}(0.0364609)
#  Gray{Float64}(0.0330579)  …  Gray{Float64}(0.0345163)

# %%
colorview(Gray, moving[:,:,sliceNum] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float64,2,Array{Float64,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.00783162)  …  Gray{Float64}(0.0083211)
#  Gray{Float64}(0.0083211)      Gray{Float64}(0.00440529)
#  Gray{Float64}(0.0141948)      Gray{Float64}(0.0083211)
#  Gray{Float64}(0.0141948)      Gray{Float64}(0.010279)
#  Gray{Float64}(0.0132159)      Gray{Float64}(0.00978953)
#  Gray{Float64}(0.0132159)   …  Gray{Float64}(0.00978953)
#  Gray{Float64}(0.0141948)      Gray{Float64}(0.0166422)
#  Gray{Float64}(0.0166422)      Gray{Float64}(0.00930005)
#  Gray{Float64}(0.0190896)      Gray{Float64}(0.010279)
#  Gray{Float64}(0.0181106)      Gray{Float64}(0.0141948)
#  Gray{Float64}(0.0186001)   …  Gray{Float64}(0.0117474)
#  Gray{Float64}(0.0146843)      Gray{Float64}(0.0117474)
#  Gray{Float64}(0.0146843)      Gray{Float64}(0.0132159)
#  ⋮                          ⋱  ⋮
#  Gray{Float64}(0.0264317)      Gray{Float64}(0.0274107)
#  Gray{Float64}(0.0259422)   …  Gray{Float64}(0.0259422)
#  Gray{Float64}(0.0274107)      Gray{Float64}(0.0293686)
#  Gray{Float64}(0.0249633)      Gray{Float64}(0.0274107)
#  Gray{Float64}(0.0244738)      Gray{Float64}(0.0279001)
#  Gray{Float64}(0.0254528)      Gray{Float64}(0.0269212)
#  Gray{Float64}(0.0293686)   …  Gray{Float64}(0.0332844)
#  Gray{Float64}(0.0313265)      Gray{Float64}(0.0298581)
#  Gray{Float64}(0.0288791)      Gray{Float64}(0.0313265)
#  Gray{Float64}(0.0244738)      Gray{Float64}(0.0313265)
#  Gray{Float64}(0.0244738)      Gray{Float64}(0.0303475)
#  Gray{Float64}(0.0254528)   …  Gray{Float64}(0.0327949)

# %%
colorview(Gray, warpped[end][:,:,sliceNum]-fixed[:,:,sliceNum] |> x->x/maximum(x))
# Out:
# 256×256 Array{Gray{Float64},2}:
#  Gray{Float64}(4.63181e-5)    …  Gray{Float64}(0.00202755)
#  Gray{Float64}(-0.00914168)      Gray{Float64}(0.0146981)
#  Gray{Float64}(-0.0214617)       Gray{Float64}(-0.000466179)
#  Gray{Float64}(-0.000654116)     Gray{Float64}(-0.00648895)
#  Gray{Float64}(-0.00206196)      Gray{Float64}(0.00288459)
#  Gray{Float64}(-0.00910118)   …  Gray{Float64}(0.00429243)
#  Gray{Float64}(-0.00933466)      Gray{Float64}(-0.00446797)
#  Gray{Float64}(0.000183628)      Gray{Float64}(0.00482754)
#  Gray{Float64}(0.000247078)      Gray{Float64}(0.0191081)
#  Gray{Float64}(-0.000535762)     Gray{Float64}(9.03283e-5)
#  Gray{Float64}(0.00157633)    …  Gray{Float64}(9.03283e-5)
#  Gray{Float64}(0.000776731)      Gray{Float64}(-6.86939e-5)
#  Gray{Float64}(-0.000205395)     Gray{Float64}(0.00293)
#  ⋮                            ⋱  ⋮
#  Gray{Float64}(0.0115867)        Gray{Float64}(-0.00909883)
#  Gray{Float64}(0.00736316)    …  Gray{Float64}(0.00010454)
#  Gray{Float64}(0.0172181)        Gray{Float64}(0.0160803)
#  Gray{Float64}(0.000257272)      Gray{Float64}(0.0174881)
#  Gray{Float64}(0.0117389)        Gray{Float64}(-0.000116663)
#  Gray{Float64}(0.00469969)       Gray{Float64}(0.00721519)
#  Gray{Float64}(-0.000441454)  …  Gray{Float64}(0.00185101)
#  Gray{Float64}(0.00797562)       Gray{Float64}(0.00748239)
#  Gray{Float64}(0.00141024)       Gray{Float64}(0.0102981)
#  Gray{Float64}(0.015925)         Gray{Float64}(-0.000590159)
#  Gray{Float64}(0.0108665)        Gray{Float64}(-0.00105885)
#  Gray{Float64}(-0.00216147)   …  Gray{Float64}(2.17337e-6)

# %%
colorview(Gray, moving[:,:,sliceNum]-fixed[:,:,sliceNum] |> x->x/maximum(x))
# Out:
# 256×256 Array{Gray{Float64},2}:
#  Gray{Float64}(-0.00871249)   …  Gray{Float64}(-0.00387222)
#  Gray{Float64}(-0.0164569)       Gray{Float64}(-0.00290416)
#  Gray{Float64}(-0.0125847)       Gray{Float64}(-0.00968054)
#  Gray{Float64}(0.0)              Gray{Float64}(-0.00968054)
#  Gray{Float64}(-0.00290416)      Gray{Float64}(0.0)
#  Gray{Float64}(-0.00774443)   …  Gray{Float64}(0.000968054)
#  Gray{Float64}(-0.00387222)      Gray{Float64}(0.00290416)
#  Gray{Float64}(0.00871249)       Gray{Float64}(-0.000968054)
#  Gray{Float64}(0.0145208)        Gray{Float64}(0.0116167)
#  Gray{Float64}(0.00968054)       Gray{Float64}(0.00290416)
#  Gray{Float64}(0.0154889)     …  Gray{Float64}(-0.00193611)
#  Gray{Float64}(0.00677638)       Gray{Float64}(0.0)
#  Gray{Float64}(0.00193611)       Gray{Float64}(0.00871249)
#  ⋮                            ⋱  ⋮
#  Gray{Float64}(-0.000968054)     Gray{Float64}(-0.018393)
#  Gray{Float64}(-0.00484027)   …  Gray{Float64}(-0.0106486)
#  Gray{Float64}(0.00484027)       Gray{Float64}(0.00871249)
#  Gray{Float64}(-0.00968054)      Gray{Float64}(0.00580833)
#  Gray{Float64}(-0.00193611)      Gray{Float64}(-0.00968054)
#  Gray{Float64}(-0.00484027)      Gray{Float64}(-0.000968054)
#  Gray{Float64}(-0.000968054)  …  Gray{Float64}(0.00484027)
#  Gray{Float64}(0.00871249)       Gray{Float64}(0.00193611)
#  Gray{Float64}(-0.00193611)      Gray{Float64}(0.00677638)
#  Gray{Float64}(-0.00193611)      Gray{Float64}(-0.00484027)
#  Gray{Float64}(-0.00580833)      Gray{Float64}(-0.0125847)
#  Gray{Float64}(-0.0154889)    …  Gray{Float64}(-0.00387222)

# %%
using MAT
# Out:
# INFO: Precompiling module MAT.

# %%
out = warpped[end].data;

# %%
matwrite("case5.mat", Dict("case5" => out))

# %%
plot(colorview(Gray, warpped[end][120,:,:]-fixed[120,:,:] |> x->x/maximum(x)))
# Out:
# WARNING: No working GUI backend found for matplotlib
# <img src="data:image/png;base64,..." />

# %%
colorview(Gray, moving[120,:,:]-fixed[120,:,:] |> x->x/maximum(x))
# Out:
# 256×106 Array{Gray{Float64},2}:
#  Gray{Float64}(-0.0483871)   …  Gray{Float64}(0.0275142)
#  Gray{Float64}(-0.0151803)      Gray{Float64}(0.0180266)
#  Gray{Float64}(-0.00189753)     Gray{Float64}(0.0113852)
#  Gray{Float64}(0.00759013)      Gray{Float64}(0.0170778)
#  Gray{Float64}(0.0313093)       Gray{Float64}(-0.0170778)
#  Gray{Float64}(0.0426945)    …  Gray{Float64}(-0.056926)
#  Gray{Float64}(0.0474383)       Gray{Float64}(0.000948767)
#  Gray{Float64}(0.0332068)       Gray{Float64}(-0.0056926)
#  Gray{Float64}(0.0322581)       Gray{Float64}(-0.044592)
#  Gray{Float64}(0.0256167)       Gray{Float64}(0.0)
#  Gray{Float64}(0.0294118)    …  Gray{Float64}(-0.250474)
#  Gray{Float64}(-0.00189753)     Gray{Float64}(-0.0294118)
#  Gray{Float64}(-0.0237192)      Gray{Float64}(0.145161)
#  ⋮                           ⋱  ⋮
#  Gray{Float64}(-0.0189753)      Gray{Float64}(0.0948767)
#  Gray{Float64}(0.016129)     …  Gray{Float64}(0.0218216)
#  Gray{Float64}(0.0398482)       Gray{Float64}(-0.0332068)
#  Gray{Float64}(0.044592)        Gray{Float64}(0.0085389)
#  Gray{Float64}(0.0379507)       Gray{Float64}(-0.000948767)
#  Gray{Float64}(0.0151803)       Gray{Float64}(0.0417457)
#  Gray{Float64}(0.000948767)  …  Gray{Float64}(0.0531309)
#  Gray{Float64}(-0.00474383)     Gray{Float64}(0.0246679)
#  Gray{Float64}(-0.0246679)      Gray{Float64}(0.00664137)
#  Gray{Float64}(-0.00379507)     Gray{Float64}(-0.0398482)
#  Gray{Float64}(0.00759013)      Gray{Float64}(-0.0370019)
#  Gray{Float64}(-0.00379507)  …  Gray{Float64}(-0.0237192)

# %%
colorview(Gray, fixed[120,:,:] |> x->x/maximum(x))
# Out:
# 256×106 ColorView{Gray}(::AxisArrays.AxisArray{Float64,2,Array{Float64,2},Tuple{AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:S,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.435331)  Gray{Float64}(0.415953)  …  Gray{Float64}(0.399279)
#  Gray{Float64}(0.426769)  Gray{Float64}(0.422713)     Gray{Float64}(0.399279)
#  Gray{Float64}(0.422262)  Gray{Float64}(0.431275)     Gray{Float64}(0.40694)
#  Gray{Float64}(0.418206)  Gray{Float64}(0.429923)     Gray{Float64}(0.411897)
#  Gray{Float64}(0.415502)  Gray{Float64}(0.424516)     Gray{Float64}(0.431726)
#  Gray{Float64}(0.4137)    Gray{Float64}(0.417305)  …  Gray{Float64}(0.473186)
#  Gray{Float64}(0.410095)  Gray{Float64}(0.414151)     Gray{Float64}(0.4831)
#  Gray{Float64}(0.415052)  Gray{Float64}(0.405588)     Gray{Float64}(0.488959)
#  Gray{Float64}(0.414601)  Gray{Float64}(0.405588)     Gray{Float64}(0.501127)
#  Gray{Float64}(0.424065)  Gray{Float64}(0.418206)     Gray{Float64}(0.477242)
#  Gray{Float64}(0.425417)  Gray{Float64}(0.427219)  …  Gray{Float64}(0.598017)
#  Gray{Float64}(0.429923)  Gray{Float64}(0.425417)     Gray{Float64}(0.593511)
#  Gray{Float64}(0.432627)  Gray{Float64}(0.426769)     Gray{Float64}(0.518251)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float64}(0.437134)  Gray{Float64}(0.422713)     Gray{Float64}(0.423164)
#  Gray{Float64}(0.418206)  Gray{Float64}(0.426318)  …  Gray{Float64}(0.459216)
#  Gray{Float64}(0.411897)  Gray{Float64}(0.423614)     Gray{Float64}(0.472735)
#  Gray{Float64}(0.411897)  Gray{Float64}(0.416854)     Gray{Float64}(0.46192)
#  Gray{Float64}(0.412348)  Gray{Float64}(0.411897)     Gray{Float64}(0.46913)
#  Gray{Float64}(0.415502)  Gray{Float64}(0.421812)     Gray{Float64}(0.470482)
#  Gray{Float64}(0.4137)    Gray{Float64}(0.416854)  …  Gray{Float64}(0.478143)
#  Gray{Float64}(0.410095)  Gray{Float64}(0.414601)     Gray{Float64}(0.479946)
#  Gray{Float64}(0.409644)  Gray{Float64}(0.423614)     Gray{Float64}(0.473186)
#  Gray{Float64}(0.39973)   Gray{Float64}(0.435331)     Gray{Float64}(0.460117)
#  Gray{Float64}(0.396124)  Gray{Float64}(0.429022)     Gray{Float64}(0.440288)
#  Gray{Float64}(0.406039)  Gray{Float64}(0.414151)  …  Gray{Float64}(0.42091)
