# %%
using NRIRHOPM
# Out:
# WARNING: Method definition mapc(Any, Number) in module ColorTypes at /Users/gnimuc/.julia/v0.5/ColorTypes/src/operations.jl:104 overwritten in module ImageCore at /Users/gnimuc/.julia/v0.5/ImageCore/src/map.jl:110.

# %%
fixed = readDIRLab("../../../Dropbox/CTdata/case5_T00-ssm.img", NRIRHOPM.DIRLab4DCT5);

# %%
nii = load("../../../Dropbox/CTdata/case5deeds_deformed.nii")
img = NRIRHOPM.readDIRLab(nii);

# %%
colorview(Gray, img[:,:,60] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float32,2,Array{Float32,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float32}:
#  Gray{Float32}(0.0152066)  …  Gray{Float32}(0.017209)
#  Gray{Float32}(0.0192127)     Gray{Float32}(0.0158548)
#  Gray{Float32}(0.0187895)     Gray{Float32}(0.0127105)
#  Gray{Float32}(0.015774)      Gray{Float32}(0.0125729)
#  Gray{Float32}(0.0126139)     Gray{Float32}(0.0142161)
#  Gray{Float32}(0.012962)   …  Gray{Float32}(0.0159603)
#  Gray{Float32}(0.013469)      Gray{Float32}(0.0143216)
#  Gray{Float32}(0.0130873)     Gray{Float32}(0.0118564)
#  Gray{Float32}(0.0151498)     Gray{Float32}(0.0164375)
#  Gray{Float32}(0.0191504)     Gray{Float32}(0.0150452)
#  Gray{Float32}(0.01911)    …  Gray{Float32}(0.011652)
#  Gray{Float32}(0.0161597)     Gray{Float32}(0.0086032)
# ...

# %%
colorview(Gray, fixed[:,:,60] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float64,2,Array{Float64,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.0175272)  …  Gray{Float64}(0.0203695)
#  Gray{Float64}(0.0198958)     Gray{Float64}(0.0194221)
#  Gray{Float64}(0.0142113)     Gray{Float64}(0.0175272)
#  Gray{Float64}(0.0142113)     Gray{Float64}(0.0170535)
#  Gray{Float64}(0.0170535)     Gray{Float64}(0.011369)
#  Gray{Float64}(0.0127901)  …  Gray{Float64}(0.0142113)
#  Gray{Float64}(0.011369)      Gray{Float64}(0.0151587)
#  Gray{Float64}(0.0170535)     Gray{Float64}(0.0161061)
#  Gray{Float64}(0.0213169)     Gray{Float64}(0.0175272)
#  Gray{Float64}(0.0132639)     Gray{Float64}(0.011369)
#  Gray{Float64}(0.014685)   …  Gray{Float64}(0.00900047)
#  Gray{Float64}(0.0170535)     Gray{Float64}(0.00994789)
# ...

# %%
vecnorm(img-fixed)
# Out:
# (109020.49f0,109020.49f0)

# %%
colorview(Gray, abs(fixed[:,:,60]-img[:,:,60]) |> x->x/maximum(x))
# Out:
# 256×256 Array{Gray{Float32},2}:
#  Gray{Float32}(0.00641736)   …  Gray{Float32}(0.00868242)
#  Gray{Float32}(0.00213138)      Gray{Float32}(0.00974104)
#  Gray{Float32}(0.011858)        Gray{Float32}(0.0130101)
#  Gray{Float32}(0.00389362)      Gray{Float32}(0.0121143)
#  Gray{Float32}(0.0120062)       Gray{Float32}(0.00733247)
#  Gray{Float32}(0.000243408)  …  Gray{Float32}(0.00438556)
#  Gray{Float32}(0.00535946)      Gray{Float32}(0.00246009)
#  Gray{Float32}(0.0107559)       Gray{Float32}(0.0114889)
#  Gray{Float32}(0.0166388)       Gray{Float32}(0.00316646)
#  Gray{Float32}(0.0153292)       Gray{Float32}(0.0095223)
#  Gray{Float32}(0.0114455)    …  Gray{Float32}(0.00685506)
#  Gray{Float32}(0.00264131)      Gray{Float32}(0.00371514)
#  Gray{Float32}(0.016486)        Gray{Float32}(0.00493006)
#  ⋮                           ⋱  ⋮
#  Gray{Float32}(0.011721)        Gray{Float32}(0.0138549)
#  Gray{Float32}(0.00130778)   …  Gray{Float32}(0.00902596)
# ...

# %%
nii32 = load("../../../Codes/deed-test_deformed.nii")
img32 = NRIRHOPM.readDIRLab(nii32);

# %%
colorview(Gray, img32[:,:,60] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float32,2,Array{Float32,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float32}:
#  Gray{Float32}(0.0158049)  …  Gray{Float32}(0.0168387)
#  Gray{Float32}(0.0140845)     Gray{Float32}(0.0172163)
#  Gray{Float32}(0.0143031)     Gray{Float32}(0.0144377)
#  Gray{Float32}(0.0154953)     Gray{Float32}(0.0116606)
#  Gray{Float32}(0.0154051)     Gray{Float32}(0.0146539)
#  Gray{Float32}(0.013914)   …  Gray{Float32}(0.0167872)
#  Gray{Float32}(0.0134568)     Gray{Float32}(0.0136825)
#  Gray{Float32}(0.0141775)     Gray{Float32}(0.00913504)
#  Gray{Float32}(0.0139151)     Gray{Float32}(0.0167017)
#  Gray{Float32}(0.0122906)     Gray{Float32}(0.0157413)
#  Gray{Float32}(0.0140089)  …  Gray{Float32}(0.0128981)
#  Gray{Float32}(0.0178337)     Gray{Float32}(0.00818919)
# ...

# %%
colorview(Gray, fixed[:,:,60] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float64,2,Array{Float64,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.0175272)  …  Gray{Float64}(0.0203695)
#  Gray{Float64}(0.0198958)     Gray{Float64}(0.0194221)
#  Gray{Float64}(0.0142113)     Gray{Float64}(0.0175272)
#  Gray{Float64}(0.0142113)     Gray{Float64}(0.0170535)
#  Gray{Float64}(0.0170535)     Gray{Float64}(0.011369)
#  Gray{Float64}(0.0127901)  …  Gray{Float64}(0.0142113)
#  Gray{Float64}(0.011369)      Gray{Float64}(0.0151587)
#  Gray{Float64}(0.0170535)     Gray{Float64}(0.0161061)
#  Gray{Float64}(0.0213169)     Gray{Float64}(0.0175272)
#  Gray{Float64}(0.0132639)     Gray{Float64}(0.011369)
#  Gray{Float64}(0.014685)   …  Gray{Float64}(0.00900047)
#  Gray{Float64}(0.0170535)     Gray{Float64}(0.00994789)
# ...

# %%
vecnorm(img32-fixed)
# Out:
# 190898.05f0

# %%
colorview(Gray, abs(fixed[:,:,60]-img32[:,:,60]) |> x->x/maximum(x))
# Out:
# 256×256 Array{Gray{Float32},2}:
#  Gray{Float32}(0.00317464)   …  Gray{Float32}(0.00634089)
#  Gray{Float32}(0.01029)         Gray{Float32}(0.00403328)
#  Gray{Float32}(6.54025f-6)      Gray{Float32}(0.00554537)
#  Gray{Float32}(0.0020737)       Gray{Float32}(0.00953413)
#  Gray{Float32}(0.00304146)      Gray{Float32}(0.00557358)
#  Gray{Float32}(0.0018113)    …  Gray{Float32}(0.00431375)
#  Gray{Float32}(0.00349781)      Gray{Float32}(0.00272252)
#  Gray{Float32}(0.00517007)      Gray{Float32}(0.0122602)
#  Gray{Float32}(0.0130631)       Gray{Float32}(0.00161976)
#  Gray{Float32}(0.00183011)      Gray{Float32}(0.00745905)
#  Gray{Float32}(0.00132999)   …  Gray{Float32}(0.00666134)
#  Gray{Float32}(0.00116944)      Gray{Float32}(0.00315631)
#  Gray{Float32}(0.0134868)       Gray{Float32}(0.00607886)
#  ⋮                           ⋱  ⋮
#  Gray{Float32}(0.00718787)      Gray{Float32}(0.00731976)
#  Gray{Float32}(0.00283663)   …  Gray{Float32}(0.00775951)
# ...

# %%
colorview(Gray, abs(fixed[:,:,60]-img64[:,:,60]) |> x->x/maximum(x))
# Out:
# 256×256 Array{Gray{Float32},2}:
#  Gray{Float32}(0.020438)    …  Gray{Float32}(0.00630029)
#  Gray{Float32}(0.0215646)      Gray{Float32}(0.00385457)
#  Gray{Float32}(0.00547736)     Gray{Float32}(0.00238732)
#  Gray{Float32}(0.00756014)     Gray{Float32}(0.0103483)
#  Gray{Float32}(0.00847031)     Gray{Float32}(0.00663666)
#  Gray{Float32}(0.0015512)   …  Gray{Float32}(0.0069966)
#  Gray{Float32}(0.0018364)      Gray{Float32}(0.00724599)
#  Gray{Float32}(0.0128232)      Gray{Float32}(0.003908)
#  Gray{Float32}(0.0202461)      Gray{Float32}(0.00379917)
#  Gray{Float32}(0.0121574)      Gray{Float32}(0.0105571)
#  Gray{Float32}(0.0177297)   …  Gray{Float32}(0.0102829)
#  Gray{Float32}(0.00261091)     Gray{Float32}(0.00862964)
#  Gray{Float32}(0.00856756)     Gray{Float32}(0.0086766)
#  ⋮                          ⋱  ⋮
#  Gray{Float32}(0.0116746)      Gray{Float32}(0.000686193)
#  Gray{Float32}(0.00796424)  …  Gray{Float32}(0.0142743)
# ...

# %%
niibest = load("../../../Codes/deeds-best_deformed.nii")
imgbest = NRIRHOPM.readDIRLab(niibest);

# %%
colorview(Gray, imgbest[:,:,60] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float32,2,Array{Float32,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float32}:
#  Gray{Float32}(0.0149853)  …  Gray{Float32}(0.0167207)
#  Gray{Float32}(0.0150412)     Gray{Float32}(0.0166581)
#  Gray{Float32}(0.0159667)     Gray{Float32}(0.0156411)
#  Gray{Float32}(0.0151317)     Gray{Float32}(0.0137448)
#  Gray{Float32}(0.0134942)     Gray{Float32}(0.014461)
#  Gray{Float32}(0.0131575)  …  Gray{Float32}(0.0151713)
#  Gray{Float32}(0.0152827)     Gray{Float32}(0.0166743)
#  Gray{Float32}(0.0144366)     Gray{Float32}(0.0152932)
#  Gray{Float32}(0.0140226)     Gray{Float32}(0.0138976)
#  Gray{Float32}(0.0170288)     Gray{Float32}(0.0148594)
#  Gray{Float32}(0.016832)   …  Gray{Float32}(0.0152839)
#  Gray{Float32}(0.0170864)     Gray{Float32}(0.0106905)
# ...

# %%
vecnorm(imgbest-fixed)
# Out:
# 108237.5f0

# %%
nii42 = load("../../../Codes/deeds42_deformed.nii")
img42 = NRIRHOPM.readDIRLab(nii42);

# %%
colorview(Gray, img42[:,:,60] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float32,2,Array{Float32,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float32}:
#  Gray{Float32}(0.0104164)  …  Gray{Float32}(0.017135)
#  Gray{Float32}(0.0121221)     Gray{Float32}(0.0147263)
#  Gray{Float32}(0.0158918)     Gray{Float32}(0.0139239)
#  Gray{Float32}(0.0174256)     Gray{Float32}(0.014438)
#  Gray{Float32}(0.0150628)     Gray{Float32}(0.0149252)
#  Gray{Float32}(0.0118303)  …  Gray{Float32}(0.0154938)
#  Gray{Float32}(0.0112093)     Gray{Float32}(0.016823)
#  Gray{Float32}(0.0116287)     Gray{Float32}(0.0167537)
#  Gray{Float32}(0.0131687)     Gray{Float32}(0.0137745)
#  Gray{Float32}(0.0172155)     Gray{Float32}(0.0132075)
#  Gray{Float32}(0.0202575)  …  Gray{Float32}(0.0154771)
#  Gray{Float32}(0.0191684)     Gray{Float32}(0.0144601)
# ...

# %%
vecnorm(img32v2-fixed)
# Out:
# 185739.72f0

# %%
vecnorm(img42v2-fixed)
# Out:
# 153745.86f0

# %%
vecnorm(img42-fixed)
# Out:
# 159271.16f0

# %%
vecnorm(img64-fixed)
# Out:
# 146390.97f0

# %%
vecnorm(img85-fixed)
# Out:
# 120375.56f0

# %%
vecnorm(imgbest-fixed)
# Out:
# 108237.5f0

# %%
vecnorm(imgSSCthin-fixed)
# Out:
# 109529.5f0

# %%
vecnorm(imgthin-fixed)
# Out:
# 108976.33f0

# %%
vecnorm(img32-fixed)
# Out:
# 190898.05f0

# %%
nii64 = load("../../../Codes/deeds64_deformed.nii")
img64 = NRIRHOPM.readDIRLab(nii64);

# %%
colorview(Gray, img64[:,:,60] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float32,2,Array{Float32,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float32}:
#  Gray{Float32}(0.0103066)  …  Gray{Float32}(0.0182364)
#  Gray{Float32}(0.0122858)     Gray{Float32}(0.0181601)
#  Gray{Float32}(0.0162636)     Gray{Float32}(0.0167797)
#  Gray{Float32}(0.0170105)     Gray{Float32}(0.0134482)
#  Gray{Float32}(0.0141217)     Gray{Float32}(0.0138194)
#  Gray{Float32}(0.0123131)  …  Gray{Float32}(0.0117903)
#  Gray{Float32}(0.012098)      Gray{Float32}(0.0126541)
#  Gray{Float32}(0.0125607)     Gray{Float32}(0.0148045)
#  Gray{Float32}(0.0141886)     Gray{Float32}(0.0162734)
#  Gray{Float32}(0.0177058)     Gray{Float32}(0.0152253)
#  Gray{Float32}(0.021134)   …  Gray{Float32}(0.0127438)
#  Gray{Float32}(0.0180955)     Gray{Float32}(0.0131042)
# ...

# %%
colorview(Gray, abs(fixed[:,:,60]-img64[:,:,60]) |> x->x/maximum(x))
# Out:
# 256×256 Array{Gray{Float32},2}:
#  Gray{Float32}(0.020438)    …  Gray{Float32}(0.00630029)
#  Gray{Float32}(0.0215646)      Gray{Float32}(0.00385457)
#  Gray{Float32}(0.00547736)     Gray{Float32}(0.00238732)
#  Gray{Float32}(0.00756014)     Gray{Float32}(0.0103483)
#  Gray{Float32}(0.00847031)     Gray{Float32}(0.00663666)
#  Gray{Float32}(0.0015512)   …  Gray{Float32}(0.0069966)
#  Gray{Float32}(0.0018364)      Gray{Float32}(0.00724599)
#  Gray{Float32}(0.0128232)      Gray{Float32}(0.003908)
#  Gray{Float32}(0.0202461)      Gray{Float32}(0.00379917)
#  Gray{Float32}(0.0121574)      Gray{Float32}(0.0105571)
#  Gray{Float32}(0.0177297)   …  Gray{Float32}(0.0102829)
#  Gray{Float32}(0.00261091)     Gray{Float32}(0.00862964)
#  Gray{Float32}(0.00856756)     Gray{Float32}(0.0086766)
#  ⋮                          ⋱  ⋮
#  Gray{Float32}(0.0116746)      Gray{Float32}(0.000686193)
#  Gray{Float32}(0.00796424)  …  Gray{Float32}(0.0142743)
# ...

# %%
nii85 = load("../../../Codes/deeds85_deformed.nii")
img85 = NRIRHOPM.readDIRLab(nii85);

# %%
colorview(Gray, abs(fixed[:,:,60]-img85[:,:,60]) |> x->x/maximum(x))
# Out:
# 256×256 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0109183)    …  Gray{Float32}(0.0121146)
#  Gray{Float32}(0.011858)        Gray{Float32}(0.0166121)
#  Gray{Float32}(0.00735177)      Gray{Float32}(0.00956402)
#  Gray{Float32}(0.00251705)      Gray{Float32}(0.00734313)
#  Gray{Float32}(0.00783071)      Gray{Float32}(0.0106917)
#  Gray{Float32}(0.0194721)    …  Gray{Float32}(0.00799694)
#  Gray{Float32}(0.0179412)       Gray{Float32}(0.00447209)
#  Gray{Float32}(0.00640586)      Gray{Float32}(0.00669482)
#  Gray{Float32}(0.0196093)       Gray{Float32}(0.00978727)
#  Gray{Float32}(0.00372914)      Gray{Float32}(0.0115797)
#  Gray{Float32}(0.00104308)   …  Gray{Float32}(0.0042514)
#  Gray{Float32}(0.000530829)     Gray{Float32}(0.00499043)
#  Gray{Float32}(0.0200604)       Gray{Float32}(0.00068989)
#  ⋮                           ⋱  ⋮
#  Gray{Float32}(0.00913469)      Gray{Float32}(0.0163518)
#  Gray{Float32}(0.00494509)   …  Gray{Float32}(0.0108983)
# ...

# %%
colorview(Gray, img85[:,:,60] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float32,2,Array{Float32,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float32}:
#  Gray{Float32}(0.0141574)  …  Gray{Float32}(0.0166361)
#  Gray{Float32}(0.0162412)     Gray{Float32}(0.0142499)
#  Gray{Float32}(0.0166415)     Gray{Float32}(0.0145888)
#  Gray{Float32}(0.0134974)     Gray{Float32}(0.0148197)
#  Gray{Float32}(0.0146644)     Gray{Float32}(0.0148457)
#  Gray{Float32}(0.019073)   …  Gray{Float32}(0.0168471)
#  Gray{Float32}(0.0171554)     Gray{Float32}(0.0166774)
#  Gray{Float32}(0.0151183)     Gray{Float32}(0.014073)
#  Gray{Float32}(0.0152017)     Gray{Float32}(0.0145177)
#  Gray{Float32}(0.0145341)     Gray{Float32}(0.0151287)
#  Gray{Float32}(0.0144437)  …  Gray{Float32}(0.0104107)
#  Gray{Float32}(0.0169901)     Gray{Float32}(0.00841962)
# ...

# %%
nii42v2 = load("../../../Codes/deeds42v2_deformed.nii")
img42v2 = NRIRHOPM.readDIRLab(nii42v2);

# %%
colorview(Gray, img42v2[:,:,60] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float32,2,Array{Float32,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float32}:
#  Gray{Float32}(0.0146231)  …  Gray{Float32}(0.0160183)
#  Gray{Float32}(0.0149786)     Gray{Float32}(0.0119495)
#  Gray{Float32}(0.019648)      Gray{Float32}(0.0133923)
#  Gray{Float32}(0.0198762)     Gray{Float32}(0.0164453)
#  Gray{Float32}(0.0159853)     Gray{Float32}(0.0147932)
#  Gray{Float32}(0.0111941)  …  Gray{Float32}(0.0109834)
#  Gray{Float32}(0.0122165)     Gray{Float32}(0.0147358)
#  Gray{Float32}(0.0104783)     Gray{Float32}(0.0155886)
#  Gray{Float32}(0.010696)      Gray{Float32}(0.0146147)
#  Gray{Float32}(0.0157636)     Gray{Float32}(0.0111639)
#  Gray{Float32}(0.0188022)  …  Gray{Float32}(0.00854964)
#  Gray{Float32}(0.0170322)     Gray{Float32}(0.0104308)
# ...

# %%
nii32v2 = load("../../../Codes/deeds32v2_deformed.nii")
img32v2 = NRIRHOPM.readDIRLab(nii32v2);

# %%
colorview(Gray, img32v2[:,:,60] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float32,2,Array{Float32,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float32}:
#  Gray{Float32}(0.0170406)  …  Gray{Float32}(0.0162595)
#  Gray{Float32}(0.0169911)     Gray{Float32}(0.0176319)
#  Gray{Float32}(0.0150165)     Gray{Float32}(0.0160547)
#  Gray{Float32}(0.0119655)     Gray{Float32}(0.0118609)
#  Gray{Float32}(0.0127391)     Gray{Float32}(0.0137069)
#  Gray{Float32}(0.0124003)  …  Gray{Float32}(0.0166471)
#  Gray{Float32}(0.0157426)     Gray{Float32}(0.0143594)
#  Gray{Float32}(0.0199867)     Gray{Float32}(0.00976023)
#  Gray{Float32}(0.0188574)     Gray{Float32}(0.0161208)
#  Gray{Float32}(0.0171957)     Gray{Float32}(0.0159014)
#  Gray{Float32}(0.0154826)  …  Gray{Float32}(0.0133261)
#  Gray{Float32}(0.0137913)     Gray{Float32}(0.00890866)
# ...

# %%
colorview(Gray, fixed[:,:,60] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float64,2,Array{Float64,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float64, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.0175272)  …  Gray{Float64}(0.0203695)
#  Gray{Float64}(0.0198958)     Gray{Float64}(0.0194221)
#  Gray{Float64}(0.0142113)     Gray{Float64}(0.0175272)
#  Gray{Float64}(0.0142113)     Gray{Float64}(0.0170535)
#  Gray{Float64}(0.0170535)     Gray{Float64}(0.011369)
#  Gray{Float64}(0.0127901)  …  Gray{Float64}(0.0142113)
#  Gray{Float64}(0.011369)      Gray{Float64}(0.0151587)
#  Gray{Float64}(0.0170535)     Gray{Float64}(0.0161061)
#  Gray{Float64}(0.0213169)     Gray{Float64}(0.0175272)
#  Gray{Float64}(0.0132639)     Gray{Float64}(0.011369)
#  Gray{Float64}(0.014685)   …  Gray{Float64}(0.00900047)
#  Gray{Float64}(0.0170535)     Gray{Float64}(0.00994789)
# ...

# %%
colorview(Gray, abs(fixed[:,:,60]-img32v2[:,:,60]) |> x->x/maximum(x))
# Out:
# 256×256 Array{Gray{Float32},2}:
#  Gray{Float32}(0.000967383)  …  Gray{Float32}(0.00688452)
#  Gray{Float32}(0.00492096)      Gray{Float32}(0.00310493)
#  Gray{Float32}(0.00116554)      Gray{Float32}(0.00256966)
#  Gray{Float32}(0.00379291)      Gray{Float32}(0.00861052)
#  Gray{Float32}(0.00718331)      Gray{Float32}(0.00368501)
#  Gray{Float32}(0.000762394)  …  Gray{Float32}(0.00381552)
#  Gray{Float32}(0.00699325)      Gray{Float32}(0.00145165)
#  Gray{Float32}(0.00459522)      Gray{Float32}(0.0104753)
#  Gray{Float32}(0.00421172)      Gray{Float32}(0.00246223)
#  Gray{Float32}(0.0062563)       Gray{Float32}(0.0072513)
#  Gray{Float32}(0.00114833)   …  Gray{Float32}(0.00693927)
#  Gray{Float32}(0.00547334)      Gray{Float32}(0.0017891)
#  Gray{Float32}(0.00129963)      Gray{Float32}(0.00618809)
#  ⋮                           ⋱  ⋮
#  Gray{Float32}(0.00561021)      Gray{Float32}(0.00948035)
#  Gray{Float32}(0.00214583)   …  Gray{Float32}(0.002521)
# ...

# %%
niithin = load("../../../Codes/deedsthin_deformed.nii")
imgthin = NRIRHOPM.readDIRLab(niithin);

# %%
colorview(Gray, imgthin[:,:,60] |> x->x/maximum(x))
# Out:
# 256×256 ColorView{Gray}(::AxisArrays.AxisArray{Float32,2,Array{Float32,2},Tuple{AxisArrays.Axis{:A,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}},AxisArrays.Axis{:R,Ranges.LinSpace{Quantity{Float32, Dimensions:{𝐋}, Units:{mm}}}}}}) with element type ColorTypes.Gray{Float32}:
#  Gray{Float32}(0.0168682)  …  Gray{Float32}(0.0172409)
#  Gray{Float32}(0.0160494)     Gray{Float32}(0.0164004)
#  Gray{Float32}(0.0149906)     Gray{Float32}(0.0136936)
#  Gray{Float32}(0.0173489)     Gray{Float32}(0.0139619)
#  Gray{Float32}(0.0180405)     Gray{Float32}(0.0149039)
#  Gray{Float32}(0.0156831)  …  Gray{Float32}(0.0158509)
#  Gray{Float32}(0.0149157)     Gray{Float32}(0.0167811)
#  Gray{Float32}(0.0152659)     Gray{Float32}(0.0141044)
#  Gray{Float32}(0.0153643)     Gray{Float32}(0.0147303)
#  Gray{Float32}(0.0147682)     Gray{Float32}(0.0155297)
#  Gray{Float32}(0.0163415)  …  Gray{Float32}(0.0101172)
#  Gray{Float32}(0.0191643)     Gray{Float32}(0.00806958)
# ...

# %%
niiSSCthin = load("../../../Codes/deedsSSC_deformed.nii")
imgSSCthin = NRIRHOPM.readDIRLab(niiSSCthin);
